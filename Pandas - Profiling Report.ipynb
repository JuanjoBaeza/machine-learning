# %%
import pandas as pd
from pandas_profiling import ProfileReport

df = pd.read_csv("datasets/dataset-ecommerce.csv", delimiter=";")

profile = ProfileReport(df)

f = df.describe()
h = df.head()
t = df.tail()
i = df.info()

print(f)
print(h)
print(t)
print(i)


#profile.to_file(output_file="/mnt/c/Temp/output.html")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6727 entries, 0 to 6726
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              6725 non-null   object
#  1   first_name      6002 non-null   object
#  2   last_name       6002 non-null   object
#  3   email           6002 non-null   object
#  4   gender          6002 non-null   object
#  5   date            6727 non-null   object
#  6   time_in_site    6002 non-null   object
#  7   num_pages       6002 non-null   float64
#  8   browser         6727 non-null   object
#  9   num_clicks      5999 non-null   object
#  10    cart_value    6727 non-null   object
#  11  conversion      6002 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 630.8+ KB
#          num_pages
# count  6002.000000
# mean     14.354715
# std      13.578914
# min       0.000000
# 25%       5.000000
# 50%      11.000000
# 75%      20.000000
# ...
