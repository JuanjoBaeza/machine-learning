# %%
import json

f = open("datasets/cm.json", encoding='utf-8')
content = f.read()

data = json.loads(content)

for i in data['data']:
    print(i)

f.close()
# Out:
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'Menores de 15 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'De 15 a 19 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'De 20 a 24 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'De 25 a 29 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'De 30 a 34 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# {'municipio_codigo': '001', 'rango_edad_de_la_madre': 'De 35 a 39 años', 'numero_nacimientos': 0, 'municipio_nombre': ' Acebeda (La)', 'sexo': 'Hombre'}
# ...

# %%
for h in data['data']:
  print(h['sexo'], h['municipio_codigo'])
# Out:
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Hombre 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Mujer 001
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Hombre 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Mujer 002
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Hombre 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Mujer 003
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Hombre 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Mujer 004
# Hombre 005
# Hombre 005
# Hombre 005
# Hombre 005
# Hombre 005
# Hombre 005
# Hombre 005
# ...
